# %%
import cv2
import torch
from ultralytics import YOLO
import mediapipe as mp
import numpy as np
from collections import deque

# %%
print(f"OpenCV: {cv2.__version__}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"MediaPipe: {mp.__version__}")
print(f"NumPy: {np.__version__}")
# Out:
# OpenCV: 4.13.0
# PyTorch: 2.2.2
# CUDA available: True
# MediaPipe: 0.10.9
# NumPy: 1.26.4

# %%
# cap = cv2.VideoCapture(0)
# print("Press 'q' to quit")

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     results = face_mesh.process(rgb_frame)
    
#     # Draw landmarks if face detected
#     if results.multi_face_landmarks:
#         for face_landmarks in results.multi_face_landmarks:
#             mp_drawing.draw_landmarks(
#                 image=frame,
#                 landmark_list=face_landmarks,
#                 connections=mp_face_mesh.FACEMESH_TESSELATION,
#                 landmark_drawing_spec=None,
#                 connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_tesselation_style()
#             )
        
#         # Display status
#         cv2.putText(frame, "Face Detected", (10, 30),
#                     cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
#     else:
#         cv2.putText(frame, "No Face", (10, 30),
#                     cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
#     cv2.imshow('MediaPipe FaceMesh', frame)
    
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
# face_mesh.close()

# %%
# Eye landmark indices
LEFT_EYE = [33, 160, 158, 133, 153, 144]
RIGHT_EYE = [362, 385, 387, 263, 373, 380]

# 3D model points for head pose
MODEL_POINTS = np.array([
    (0.0, 0.0, 0.0),
    (0.0, -330.0, -65.0),
    (-225.0, 170.0, -135.0),
    (225.0, 170.0, -135.0),
    (-150.0, -150.0, -125.0),
    (150.0, -150.0, -125.0)
], dtype=np.float64)

# Thresholds
EAR_THRESHOLD = 0.25
YAW_THRESHOLD = 32

# %%
def calculate_distance(point1, point2):
    return np.sqrt((point1.x - point2.x)**2 + (point1.y - point2.y)**2)

def calculate_ear(eye_landmarks):
    vertical1 = calculate_distance(eye_landmarks[1], eye_landmarks[5])
    vertical2 = calculate_distance(eye_landmarks[2], eye_landmarks[4])
    horizontal = calculate_distance(eye_landmarks[0], eye_landmarks[3])
    ear = (vertical1 + vertical2) / (2.0 * horizontal)
    return ear

def get_eye_landmarks(face_landmarks, eye_indices):
    return [face_landmarks.landmark[i] for i in eye_indices]

# %%
def get_2d_points(face_landmarks, img_width, img_height):
    indices = [1, 152, 33, 263, 61, 291]
    points_2d = []
    for idx in indices:
        landmark = face_landmarks.landmark[idx]
        x = int(landmark.x * img_width)
        y = int(landmark.y * img_height)
        points_2d.append([x, y])
    return np.array(points_2d, dtype=np.float64)

def get_head_pose(face_landmarks, img_width, img_height):
    image_points = get_2d_points(face_landmarks, img_width, img_height)
    
    focal_length = img_width
    center = (img_width / 2, img_height / 2)
    camera_matrix = np.array([
        [focal_length, 0, center[0]],
        [0, focal_length, center[1]],
        [0, 0, 1]
    ], dtype=np.float64)
    
    dist_coeffs = np.zeros((4, 1))
    
    success, rotation_vector, translation_vector = cv2.solvePnP(
        MODEL_POINTS,
        image_points,
        camera_matrix,
        dist_coeffs,
        flags=cv2.SOLVEPNP_ITERATIVE
    )
    
    rotation_matrix, _ = cv2.Rodrigues(rotation_vector)
    pose_matrix = cv2.hconcat((rotation_matrix, translation_vector))
    _, _, _, _, _, _, euler_angles = cv2.decomposeProjectionMatrix(pose_matrix)
    
    pitch = euler_angles[0][0]
    yaw = euler_angles[1][0]
    roll = euler_angles[2][0]
    
    return pitch, yaw, roll

# %%
class FocusScorer:
    def __init__(self):
        # Thresholds
        self.EAR_THRESHOLD = 0.21
        self.EYE_CLOSED_FRAMES_SHORT = 15  
        self.EYE_CLOSED_FRAMES_LONG = 45   
        
        self.PHONE_FRAMES_SHORT = 5
        self.PHONE_FRAMES_LONG = 15
        
        self.eye_counter = 0
        self.phone_counter = 0
        
        self.prev_score = 100
        self.alpha = 0.2  # smoothing factor

    def update(self, ear, yaw, gaze_direction, phone_detected):
        """
        ear: float (eye aspect ratio)
        yaw: float (head yaw angle in degrees)
        gaze_direction: string ("center", "slight", "away")
        phone_detected: bool
        """

        if ear < self.EAR_THRESHOLD:
            self.eye_counter += 1
        else:
            self.eye_counter = 0

        if self.eye_counter > self.EYE_CLOSED_FRAMES_LONG:
            eye_penalty = 30
        elif self.eye_counter > self.EYE_CLOSED_FRAMES_SHORT:
            eye_penalty = 15
        else:
            eye_penalty = 0

        
        if gaze_direction == "center":
            gaze_penalty = 0
        elif gaze_direction == "slight":
            gaze_penalty = 10
        else:  # "away"
            gaze_penalty = 20
        if abs(yaw) < 10:
            head_penalty = 0
        elif abs(yaw) < 20:
            head_penalty = 10
        else:
            head_penalty = 20

        
        if phone_detected:
            self.phone_counter += 1
        else:
            self.phone_counter = 0

        if self.phone_counter > self.PHONE_FRAMES_LONG:
            phone_penalty = 40
        elif self.phone_counter > self.PHONE_FRAMES_SHORT:
            phone_penalty = 20
        else:
            phone_penalty = 0


        raw_score = 100 - (
            eye_penalty +
            gaze_penalty +
            head_penalty +
            phone_penalty
        )

        raw_score = max(0, min(100, raw_score))


        smooth_score = (
            self.alpha * raw_score +
            (1 - self.alpha) * self.prev_score
        )

        self.prev_score = smooth_score
        return round(smooth_score, 2)

# %%
# Initialize YOLO
model = YOLO('yolo12m.pt')

# Initialize MediaPipe
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

face_mesh = mp_face_mesh.FaceMesh(
    static_image_mode=False,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

print("Models initialized!")
# Out:
# Models initialized!

# %%
cap = cv2.VideoCapture(0)
print("Press 'q' to quit")

focus_scorer = FocusScorer()

low_focus_counter = 0
LOW_FOCUS_THRESHOLD = 50
LOW_FOCUS_FRAMES = 30   # ~1 sec at 30 FPS

while True:
    ret, frame = cap.read()
    if not ret:
        break

    img_height, img_width = frame.shape[:2]

    yolo_results = model(frame)
    phone_detected = False

    for box in yolo_results[0].boxes:
        if int(box.cls[0]) == 67 and float(box.conf[0]) > 0.4:
            phone_detected = True
            break

    annotated_frame = yolo_results[0].plot()


    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    face_results = face_mesh.process(rgb_frame)
    face_detected = face_results.multi_face_landmarks is not None

    avg_ear = 0
    yaw = 0
    gaze_direction = "center"

    if face_detected:
        face_landmarks = face_results.multi_face_landmarks[0]

        mp_drawing.draw_landmarks(
            image=annotated_frame,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_TESSELATION,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_tesselation_style()
        )

        # EAR
        left_eye = get_eye_landmarks(face_landmarks, LEFT_EYE)
        right_eye = get_eye_landmarks(face_landmarks, RIGHT_EYE)

        left_ear = calculate_ear(left_eye)
        right_ear = calculate_ear(right_eye)
        avg_ear = (left_ear + right_ear) / 2.0

        # Head Pose
        pitch, yaw, roll = get_head_pose(face_landmarks, img_width, img_height)

        # Gaze Category
        if abs(yaw) < 10:
            gaze_direction = "center"
        elif abs(yaw) < 20:
            gaze_direction = "slight"
        else:
            gaze_direction = "away"

        # Display EAR & Yaw
        cv2.putText(annotated_frame, f"EAR: {avg_ear:.3f}", (10, 100),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2)

        cv2.putText(annotated_frame, f"Yaw: {yaw:.1f}", (10, 135),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)


    # FOCUS SCORE COMPUTATION
    if face_detected:
        focus_score = focus_scorer.update(
            ear=avg_ear,
            yaw=yaw,
            gaze_direction=gaze_direction,
            phone_detected=phone_detected
        )
    else:
        focus_score = focus_scorer.update(
            ear=0,
            yaw=30,
            gaze_direction="away",
            phone_detected=phone_detected
        )


    focus_score = 0 if focus_score is None else focus_score

    if focus_score < LOW_FOCUS_THRESHOLD:
        low_focus_counter += 1
    else:
        low_focus_counter = 0

    show_alert = low_focus_counter > LOW_FOCUS_FRAMES

    cv2.putText(annotated_frame, f"Focus Score: {focus_score}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,255), 2)

    bar_width = int((focus_score / 100) * 200)

    cv2.rectangle(annotated_frame, (10, 50), (210, 75), (50,50,50), -1)

    if focus_score >= 70:
        bar_color = (0, 255, 0)       # Green
    elif focus_score >= 40:
        bar_color = (0, 255, 255)     # Yellow
    else:
        bar_color = (0, 0, 255)       # Red

    cv2.rectangle(annotated_frame, (10, 50),
                  (10 + bar_width, 75), bar_color, -1)

    if show_alert:

        overlay = annotated_frame.copy()
        cv2.rectangle(overlay, (0, 0),
                      (img_width, img_height), (0, 0, 255), -1)
        cv2.addWeighted(overlay, 0.15,
                        annotated_frame, 0.85, 0, annotated_frame)

        cv2.putText(
            annotated_frame,
            "GET BACK TO WORK!",
            (img_width // 4, img_height // 2),
            cv2.FONT_HERSHEY_SIMPLEX,
            1.2,
            (0, 0, 255),
            3
        )

    phone_text = "PHONE: YES" if phone_detected else "PHONE: NO"
    phone_color = (0,0,255) if phone_detected else (0,255,0)

    cv2.putText(annotated_frame, phone_text, (10, 170),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, phone_color, 2)

    face_text = "FACE: YES" if face_detected else "FACE: NO"
    face_color = (0,255,0) if face_detected else (0,0,255)

    cv2.putText(annotated_frame, face_text, (10, 205),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, face_color, 2)

    cv2.imshow('FocusAI - Attention Detection', annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
face_mesh.close()
# Out:
# Press 'q' to quit
#
# 0: 480x640 4 persons, 384.0ms
# Speed: 3.4ms preprocess, 384.0ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.7ms
# Speed: 3.2ms preprocess, 41.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 36.3ms
# Speed: 2.7ms preprocess, 36.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 35.1ms
# Speed: 1.8ms preprocess, 35.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 31.9ms
# Speed: 2.8ms preprocess, 31.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 31.2ms
# Speed: 2.4ms preprocess, 31.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 35.2ms
# Speed: 2.4ms preprocess, 35.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 39.0ms
# Speed: 1.4ms preprocess, 39.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 31.2ms
# Speed: 1.9ms preprocess, 31.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.1ms
# Speed: 1.9ms preprocess, 41.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 36.2ms
# Speed: 2.5ms preprocess, 36.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 49.1ms
# Speed: 1.7ms preprocess, 49.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.4ms
# Speed: 2.3ms preprocess, 42.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.2ms
# Speed: 1.8ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 28.0ms
# Speed: 1.6ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 27.3ms
# Speed: 1.8ms preprocess, 27.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 28.0ms
# Speed: 1.5ms preprocess, 28.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 30.3ms
# Speed: 2.2ms preprocess, 30.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 26.2ms
# Speed: 2.1ms preprocess, 26.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 31.5ms
# Speed: 1.9ms preprocess, 31.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 26.1ms
# Speed: 1.3ms preprocess, 26.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 30.0ms
# Speed: 1.4ms preprocess, 30.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 25.6ms
# Speed: 1.6ms preprocess, 25.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 25.8ms
# Speed: 1.3ms preprocess, 25.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 25.2ms
# Speed: 1.3ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 28.7ms
# Speed: 1.3ms preprocess, 28.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 29.8ms
# Speed: 1.4ms preprocess, 29.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.8ms
# Speed: 2.1ms preprocess, 27.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.2ms
# Speed: 1.3ms preprocess, 27.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 30.6ms
# Speed: 1.7ms preprocess, 30.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.3ms
# Speed: 1.8ms preprocess, 26.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.3ms
# Speed: 1.7ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 29.9ms
# Speed: 1.9ms preprocess, 29.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.8ms
# Speed: 1.2ms preprocess, 26.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 31.1ms
# Speed: 1.5ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.3ms
# Speed: 1.5ms preprocess, 27.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 32.3ms
# Speed: 2.9ms preprocess, 32.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.8ms
# Speed: 1.5ms preprocess, 29.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.2ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.7ms
# Speed: 1.6ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 28.7ms
# Speed: 1.4ms preprocess, 28.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 32.0ms
# Speed: 2.8ms preprocess, 32.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 36.1ms
# Speed: 1.7ms preprocess, 36.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.8ms
# Speed: 1.2ms preprocess, 24.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.7ms
# Speed: 1.2ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 30.4ms
# Speed: 2.2ms preprocess, 30.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.5ms
# Speed: 1.2ms preprocess, 24.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 36.3ms
# Speed: 1.7ms preprocess, 36.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 22.4ms
# Speed: 1.6ms preprocess, 22.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.6ms
# Speed: 1.5ms preprocess, 22.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 1.3ms preprocess, 23.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.5ms preprocess, 23.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.5ms
# Speed: 1.3ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.5ms
# Speed: 1.7ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.9ms
# Speed: 1.2ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.2ms
# Speed: 1.3ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.5ms
# Speed: 1.6ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.2ms
# Speed: 1.5ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 25.5ms
# Speed: 1.5ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 24.7ms
# Speed: 1.5ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.5ms
# Speed: 1.5ms preprocess, 24.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 31.5ms
# Speed: 1.8ms preprocess, 31.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.3ms
# Speed: 1.3ms preprocess, 23.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.2ms
# Speed: 1.4ms preprocess, 23.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.0ms
# Speed: 1.5ms preprocess, 23.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.7ms
# Speed: 1.2ms preprocess, 24.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.9ms
# Speed: 1.7ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.0ms
# Speed: 1.6ms preprocess, 25.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.5ms
# Speed: 1.7ms preprocess, 24.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.7ms
# Speed: 1.6ms preprocess, 22.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.9ms
# Speed: 1.3ms preprocess, 22.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.1ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.4ms preprocess, 20.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.3ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.8ms
# Speed: 1.2ms preprocess, 25.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.8ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.4ms
# Speed: 1.6ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.8ms
# Speed: 1.4ms preprocess, 25.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.3ms
# Speed: 1.4ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.0ms
# Speed: 1.7ms preprocess, 29.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.5ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.4ms preprocess, 20.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 1.5ms preprocess, 23.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.5ms
# Speed: 1.2ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 22.2ms
# Speed: 1.6ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.5ms preprocess, 20.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.6ms
# Speed: 1.2ms preprocess, 21.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.4ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.1ms
# Speed: 1.2ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 33.4ms
# Speed: 1.2ms preprocess, 33.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.6ms preprocess, 20.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.6ms
# Speed: 1.4ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.6ms
# Speed: 1.8ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.5ms
# Speed: 1.2ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.0ms
# Speed: 1.7ms preprocess, 21.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 27.0ms
# Speed: 1.2ms preprocess, 27.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.2ms
# Speed: 1.5ms preprocess, 23.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 1.3ms preprocess, 23.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.7ms
# Speed: 1.9ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 27.7ms
# Speed: 1.6ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.7ms
# Speed: 1.4ms preprocess, 20.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.1ms
# Speed: 1.6ms preprocess, 20.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.4ms
# Speed: 1.2ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.2ms
# Speed: 1.6ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 24.4ms
# Speed: 1.2ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.9ms
# Speed: 1.6ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.7ms
# Speed: 1.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.9ms
# Speed: 1.7ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.2ms
# Speed: 1.3ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 1.8ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.5ms preprocess, 23.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.1ms
# Speed: 1.7ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.1ms
# Speed: 1.2ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 26.1ms
# Speed: 1.3ms preprocess, 26.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.8ms
# Speed: 1.5ms preprocess, 27.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tie, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.6ms
# Speed: 1.2ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.6ms
# Speed: 1.3ms preprocess, 25.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.7ms preprocess, 22.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.8ms preprocess, 20.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.5ms
# Speed: 1.2ms preprocess, 20.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.4ms preprocess, 23.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.9ms
# Speed: 1.1ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.2ms
# Speed: 1.3ms preprocess, 20.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.8ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.8ms
# Speed: 1.5ms preprocess, 23.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.1ms
# Speed: 1.7ms preprocess, 29.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.7ms
# Speed: 1.2ms preprocess, 20.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.9ms
# Speed: 1.1ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.7ms
# Speed: 1.3ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.6ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.6ms
# Speed: 1.5ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.2ms
# Speed: 1.4ms preprocess, 24.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.7ms
# Speed: 1.2ms preprocess, 26.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.6ms
# Speed: 1.7ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.0ms
# Speed: 1.3ms preprocess, 26.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 27.4ms
# Speed: 1.9ms preprocess, 27.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.7ms
# Speed: 1.7ms preprocess, 23.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.0ms
# Speed: 1.6ms preprocess, 29.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.4ms
# Speed: 1.6ms preprocess, 29.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 29.8ms
# Speed: 1.7ms preprocess, 29.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 28.3ms
# Speed: 1.7ms preprocess, 28.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 27.0ms
# Speed: 1.4ms preprocess, 27.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 24.7ms
# Speed: 1.6ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 24.5ms
# Speed: 1.4ms preprocess, 24.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 28.2ms
# Speed: 1.4ms preprocess, 28.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 23.8ms
# Speed: 1.4ms preprocess, 23.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 23.5ms
# Speed: 1.5ms preprocess, 23.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 24.8ms
# Speed: 1.4ms preprocess, 24.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 26.3ms
# Speed: 1.4ms preprocess, 26.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 28.8ms
# Speed: 1.5ms preprocess, 28.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.3ms
# Speed: 1.4ms preprocess, 29.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 24.6ms
# Speed: 1.3ms preprocess, 24.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 30.9ms
# Speed: 1.5ms preprocess, 30.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.8ms
# Speed: 1.7ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 28.8ms
# Speed: 1.8ms preprocess, 28.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 26.5ms
# Speed: 1.4ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 23.2ms
# Speed: 1.5ms preprocess, 23.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 25.6ms
# Speed: 1.6ms preprocess, 25.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.5ms
# Speed: 1.3ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 29.1ms
# Speed: 1.5ms preprocess, 29.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.2ms
# Speed: 1.7ms preprocess, 26.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.6ms
# Speed: 1.3ms preprocess, 24.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.3ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 3.4ms preprocess, 23.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 remote, 23.4ms
# Speed: 1.6ms preprocess, 23.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 1.6ms preprocess, 23.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 remote, 24.2ms
# Speed: 1.4ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 remote, 23.0ms
# Speed: 1.3ms preprocess, 23.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.0ms
# Speed: 1.7ms preprocess, 23.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 24.2ms
# Speed: 1.4ms preprocess, 24.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.7ms
# Speed: 1.6ms preprocess, 22.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 1.6ms preprocess, 23.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 29.5ms
# Speed: 1.6ms preprocess, 29.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.7ms
# Speed: 1.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.7ms
# Speed: 1.1ms preprocess, 22.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.4ms
# Speed: 1.5ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.4ms
# Speed: 1.5ms preprocess, 26.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 23.9ms
# Speed: 1.3ms preprocess, 23.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 23.6ms
# Speed: 1.3ms preprocess, 23.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 cell phone, 24.6ms
# Speed: 1.3ms preprocess, 24.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.9ms
# Speed: 1.2ms preprocess, 21.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.0ms
# Speed: 1.3ms preprocess, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.6ms
# Speed: 1.5ms preprocess, 22.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.8ms
# Speed: 1.5ms preprocess, 22.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 24.6ms
# Speed: 1.6ms preprocess, 24.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 22.4ms
# Speed: 1.6ms preprocess, 22.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.9ms
# Speed: 1.4ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.8ms
# Speed: 1.2ms preprocess, 21.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.3ms
# Speed: 1.4ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.3ms
# Speed: 1.6ms preprocess, 25.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 24.7ms
# Speed: 2.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 21.8ms
# Speed: 1.5ms preprocess, 21.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 23.6ms
# Speed: 1.7ms preprocess, 23.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 21.9ms
# Speed: 1.6ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 22.2ms
# Speed: 1.3ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 23.9ms
# Speed: 1.2ms preprocess, 23.9ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 22.5ms
# Speed: 1.3ms preprocess, 22.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 22.7ms
# Speed: 1.3ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 22.6ms
# Speed: 1.8ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 27.8ms
# Speed: 1.5ms preprocess, 27.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 23.4ms
# Speed: 1.5ms preprocess, 23.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 22.4ms
# Speed: 1.5ms preprocess, 22.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.9ms
# Speed: 1.4ms preprocess, 22.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 dining table, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 23.7ms
# Speed: 1.6ms preprocess, 23.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.5ms
# Speed: 1.7ms preprocess, 22.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 23.3ms
# Speed: 1.7ms preprocess, 23.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 27.1ms
# Speed: 1.4ms preprocess, 27.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 24.1ms
# Speed: 1.4ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 2.1ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 21.4ms
# Speed: 1.5ms preprocess, 21.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 26.5ms
# Speed: 1.7ms preprocess, 26.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 32.5ms
# Speed: 1.3ms preprocess, 32.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.8ms
# Speed: 1.2ms preprocess, 21.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 22.6ms
# Speed: 1.7ms preprocess, 22.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 29.6ms
# Speed: 1.7ms preprocess, 29.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 24.8ms
# Speed: 1.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 24.7ms
# Speed: 1.3ms preprocess, 24.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.0ms
# Speed: 1.8ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 23.3ms
# Speed: 1.6ms preprocess, 23.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 24.6ms
# Speed: 1.5ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 25.4ms
# Speed: 1.8ms preprocess, 25.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.9ms
# Speed: 1.3ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.1ms
# Speed: 1.6ms preprocess, 21.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.4ms
# Speed: 1.2ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 21.1ms
# ...
# Speed: 1.2ms preprocess, 23.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.3ms
# Speed: 23.3ms preprocess, 22.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 23.0ms
# Speed: 1.2ms preprocess, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.0ms
# Speed: 1.2ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.4ms
# Speed: 1.5ms preprocess, 22.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.7ms
# Speed: 1.4ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.7ms
# Speed: 1.3ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 cell phone, 22.3ms
# Speed: 1.6ms preprocess, 22.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 24.6ms
# Speed: 1.9ms preprocess, 24.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 cell phone, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.4ms
# Speed: 1.2ms preprocess, 22.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.4ms
# Speed: 1.3ms preprocess, 22.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 20.6ms
# Speed: 1.8ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 cell phone, 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.8ms
# Speed: 1.3ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 24.1ms
# Speed: 2.2ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 20.8ms
# Speed: 1.2ms preprocess, 20.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 29.6ms
# Speed: 1.4ms preprocess, 29.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.5ms
# Speed: 1.6ms preprocess, 23.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 28.0ms
# Speed: 1.2ms preprocess, 28.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 20.5ms
# Speed: 1.2ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 21.1ms
# Speed: 1.8ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 21.5ms
# Speed: 1.2ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 24.7ms
# Speed: 1.3ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 20.3ms
# Speed: 1.5ms preprocess, 20.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 20.3ms
# Speed: 1.3ms preprocess, 20.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 24.9ms
# Speed: 1.7ms preprocess, 24.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.0ms
# Speed: 1.3ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.2ms
# Speed: 1.2ms preprocess, 23.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 31.6ms
# Speed: 1.6ms preprocess, 31.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 27.6ms
# Speed: 1.3ms preprocess, 27.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.1ms
# Speed: 1.8ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 22.3ms
# Speed: 1.4ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.2ms
# Speed: 1.8ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 26.5ms
# Speed: 1.5ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 25.4ms
# Speed: 2.3ms preprocess, 25.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 20.9ms
# Speed: 1.4ms preprocess, 20.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.3ms
# Speed: 1.7ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 26.8ms
# Speed: 1.6ms preprocess, 26.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.5ms
# Speed: 1.7ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 cell phone, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.1ms
# Speed: 1.4ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.9ms
# Speed: 1.5ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 21.1ms
# Speed: 1.2ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.3ms
# Speed: 1.5ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 cell phone, 21.6ms
# Speed: 1.3ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 25.6ms
# Speed: 2.3ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 24.8ms
# Speed: 1.2ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 21.4ms
# Speed: 1.2ms preprocess, 21.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 29.0ms
# Speed: 1.9ms preprocess, 29.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 24.5ms
# Speed: 1.5ms preprocess, 24.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cell phone, 23.9ms
# Speed: 1.2ms preprocess, 23.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 21.7ms
# Speed: 1.6ms preprocess, 21.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 22.7ms
# Speed: 1.6ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 24.2ms
# Speed: 1.5ms preprocess, 24.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 28.8ms
# Speed: 1.4ms preprocess, 28.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 23.1ms
# Speed: 1.4ms preprocess, 23.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.0ms
# Speed: 1.6ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 25.5ms
# Speed: 1.6ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 30.3ms
# Speed: 1.5ms preprocess, 30.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.9ms
# Speed: 1.5ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 20.7ms
# Speed: 1.4ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 22.5ms
# Speed: 1.7ms preprocess, 22.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 23.5ms
# Speed: 1.5ms preprocess, 23.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.9ms
# Speed: 1.2ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.0ms
# Speed: 1.6ms preprocess, 22.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 22.5ms
# Speed: 1.2ms preprocess, 22.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.3ms
# Speed: 1.6ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 24.8ms
# Speed: 1.6ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 20.7ms
# Speed: 1.2ms preprocess, 20.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 23.5ms
# Speed: 1.6ms preprocess, 23.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.0ms
# Speed: 1.3ms preprocess, 21.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 23.7ms
# Speed: 1.5ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 27.3ms
# Speed: 1.3ms preprocess, 27.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
